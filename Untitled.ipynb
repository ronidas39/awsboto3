# %%
import boto3

# %%
ec2_client=boto3.client("ec2")

# %%
x=ec2_client.describe_instances()

# %%
instances=x["Reservations"][0]["Instances"]

# %%
len(instances)
# Out:
# 3

# %%
len(x["Reservations"])
# Out:
# 3

# %%
x["Reservations"][1]
# Out:
# {'Groups': [],
#  'Instances': [{'AmiLaunchIndex': 2,
#    'ImageId': 'ami-03657b56516ab7912',
#    'InstanceId': 'i-0555eca1e99164c22',
#    'InstanceType': 't2.micro',
#    'LaunchTime': datetime.datetime(2020, 10, 28, 19, 55, 44, tzinfo=tzutc()),
#    'Monitoring': {'State': 'disabled'},
#    'Placement': {'AvailabilityZone': 'us-east-2c',
#     'GroupName': '',
#     'Tenancy': 'default'},
#    'PrivateDnsName': 'ip-172-31-46-115.us-east-2.compute.internal',
#    'PrivateIpAddress': '172.31.46.115',
#    'ProductCodes': [],
#    'PublicDnsName': 'ec2-18-191-68-229.us-east-2.compute.amazonaws.com',
#    'PublicIpAddress': '18.191.68.229',
#    'State': {'Code': 16, 'Name': 'running'},
#    'StateTransitionReason': '',
#    'SubnetId': 'subnet-0dc6ae41',
#    'VpcId': 'vpc-06f85a6d',
#    'Architecture': 'x86_64',
#    'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#      'Ebs': {'AttachTime': datetime.datetime(2020, 10, 28, 19, 55, 45, tzinfo=tzutc()),
# ...
